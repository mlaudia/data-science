# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Hint: read_csv(), head()
sales = pd.read_csv("kc_house_data.csv")
df = pd.DataFrame(sales.head(5))
df
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
#b) wybrać ręcznie oba rodzaje zmiennych
print(df.columns)

house_categorical_df = [df['id'], df['date'], df['zipcode'], df['waterfront'], df['view'], df['grade'], df['condition']]
print(house_categorical_df)

house_numerical_df = [df['price'], df['bathrooms'], df['bedrooms'], df['sqft_living'], df['sqft_living15'], 
                      df['sqft_lot15'], df['sqft_lot'], df['sqft_basement'], df['floors'], df['sqft_above'],
                     df['sqft_basement'], df['lat'], df['long']]
print(house_numerical_df)

#yr_built & yr_renovated?
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')
# [0    7129300520
# 1    6414100192
# 2    5631500400
# 3    2487200875
# 4    1954400510
# Name: id, dtype: int64, 0    20141013T000000
# 1    20141209T000000
# 2    20150225T000000
# 3    20141209T000000
# 4    20150218T000000
# Name: date, dtype: object, 0    98178
# 1    98125
# 2    98028
# 3    98136
# 4    98074
# Name: zipcode, dtype: int64, 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: waterfront, dtype: int64, 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: view, dtype: int64, 0    7
# 1    7
# 2    6
# 3    7
# 4    8
# Name: grade, dtype: int64, 0    3
# 1    3
# 2    3
# 3    5
# 4    3
# Name: condition, dtype: int64]
# [0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64, 0    1.00
# 1    2.25
# 2    1.00
# 3    3.00
# 4    2.00
# Name: bathrooms, dtype: float64, 0    3
# 1    3
# 2    2
# 3    4
# 4    3
# Name: bedrooms, dtype: int64, 0    1180
# 1    2570
# 2     770
# 3    1960
# 4    1680
# Name: sqft_living, dtype: int64, 0    1340
# 1    1690
# 2    2720
# 3    1360
# 4    1800
# Name: sqft_living15, dtype: int64, 0    5650
# 1    7639
# 2    8062
# 3    5000
# 4    7503
# Name: sqft_lot15, dtype: int64, 0     5650
# 1     7242
# 2    10000
# 3     5000
# 4     8080
# Name: sqft_lot, dtype: int64, 0      0
# 1    400
# 2      0
# 3    910
# 4      0
# Name: sqft_basement, dtype: int64, 0    1.0
# 1    2.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: floors, dtype: float64, 0    1180
# 1    2170
# 2     770
# 3    1050
# 4    1680
# Name: sqft_above, dtype: int64, 0      0
# 1    400
# 2      0
# 3    910
# 4      0
# Name: sqft_basement, dtype: int64, 0    47.5112
# 1    47.7210
# 2    47.7379
# 3    47.5208
# 4    47.6168
# Name: lat, dtype: float64, 0   -122.257
# 1   -122.319
# 2   -122.233
# 3   -122.393
# 4   -122.045
# Name: long, dtype: float64]

# %%
#c)
#Your code:

sales = pd.read_csv("kc_house_data.csv")
df = pd.DataFrame(sales)
df = df.sort_index(axis=1,ascending=True)
df.describe().drop(columns=['condition', 'grade', 'id', 'zipcode', 'view', 'waterfront'])

#Hint: Function describe()
# Out:
#           bathrooms      bedrooms        floors           lat          long  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       2.114757      3.370842      1.494309     47.560053   -122.213896
# std        0.770163      0.930062      0.539989      0.138564      0.140828
# min        0.000000      0.000000      1.000000     47.155900   -122.519000
# 25%        1.750000      3.000000      1.000000     47.471000   -122.328000
# 50%        2.250000      3.000000      1.500000     47.571800   -122.230000
# 75%        2.500000      4.000000      2.000000     47.678000   -122.125000
# max        8.000000     33.000000      3.500000     47.777600   -121.315000
#
#               price    sqft_above  sqft_basement   sqft_living  sqft_living15  \
# count  2.161300e+04  21613.000000   21613.000000  21613.000000   21613.000000
# mean   5.400881e+05   1788.390691     291.509045   2079.899736    1986.552492
# std    3.671272e+05    828.090978     442.575043    918.440897     685.391304
# min    7.500000e+04    290.000000       0.000000    290.000000     399.000000
# 25%    3.219500e+05   1190.000000       0.000000   1427.000000    1490.000000
# 50%    4.500000e+05   1560.000000       0.000000   1910.000000    1840.000000
# 75%    6.450000e+05   2210.000000     560.000000   2550.000000    2360.000000
# max    7.700000e+06   9410.000000    4820.000000  13540.000000    6210.000000
#
#            sqft_lot     sqft_lot15      yr_built  yr_renovated
# count  2.161300e+04   21613.000000  21613.000000  21613.000000
# mean   1.510697e+04   12768.455652   1971.005136     84.402258
# std    4.142051e+04   27304.179631     29.373411    401.679240
# min    5.200000e+02     651.000000   1900.000000      0.000000
# 25%    5.040000e+03    5100.000000   1951.000000      0.000000
# 50%    7.618000e+03    7620.000000   1975.000000      0.000000
# 75%    1.068800e+04   10083.000000   1997.000000      0.000000
# max    1.651359e+06  871200.000000   2015.000000   2015.000000

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
#Hint plt.scatter
df.plot.scatter(x='sqft_living',y='price')

# %%
#b)
#Your code:
df2 = df.loc[(df['bedrooms'] == 3) & (df['bathrooms'] == 2) & (df['floors'] == 2)]
x2 = df2['grade']
y2 = df2['price']

x = df['grade']
y = df['price']
plt.scatter(x,y)
plt.scatter(x2,y2)

#or:
#df.plot.scatter(x='grade',y='price')

# %%
#c)
#Your code:
x = df['zipcode']
y = df['price']
plt.scatter(x,y)

# %%
#Your code:
x = df['long']
y = df['lat']
colors = df['grade']
plt.scatter(x, y, c = colors)

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
#from pylab import rcParams

x = df['grade']
y = df['price']
df.boxplot(column = 'price', by = 'grade')

#Hint: plt.boxplot

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:
mosaic(df, ['condition', 'grade'])
plt.show()

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
df2 = df.loc[(df['bedrooms'] == 3) & (df['bathrooms'] == 2) & (df['floors'] == 2)]
df2.drop(columns=['condition', 'grade', 'id', 'zipcode', 'view', 'waterfront']).head(10)

#Hint: pandas.DataFrame.loc
# Out:
#       bathrooms  bedrooms             date  floors      lat     long  \
# 16          2.0         3  20140731T000000     2.0  47.7277 -121.962
# 150         2.0         3  20140820T000000     2.0  47.6838 -122.353
# 294         2.0         3  20140709T000000     2.0  47.5717 -122.375
# 365         2.0         3  20150130T000000     2.0  47.4853 -121.709
# 462         2.0         3  20141104T000000     2.0  47.3912 -122.167
# 733         2.0         3  20140715T000000     2.0  47.7591 -122.280
# 822         2.0         3  20140901T000000     2.0  47.6347 -122.396
# 894         2.0         3  20140811T000000     2.0  47.5260 -122.361
# 1175        2.0         3  20140821T000000     2.0  47.6748 -122.385
# 1360        2.0         3  20150108T000000     2.0  47.6480 -122.395
#
#           price  sqft_above  sqft_basement  sqft_living  sqft_living15  \
# 16     395000.0        1890              0         1890           1890
# 150    532170.0        1360              0         1360           1500
# 294    550000.0        1270            700         1970           2390
# 365    465000.0        1840              0         1840           1380
# 462    230000.0        1510              0         1510           1570
# 733    550000.0        2110            270         2380           2030
# 822   1100000.0        1890           1120         3010           2688
# 894    209000.0        1020            210         1230           1260
# 1175   505000.0        1500              0         1500           1550
# 1360   815000.0        1560            750         2310           2000
#
#       sqft_lot  sqft_lot15  yr_built  yr_renovated
# 16       14040       14018      1994             0
# 150       3090        3090      1990             0
# 294       4166        4166      1929             0
# 365      40438       44049      1994             0
# 462       3413        3777      1985             0
# 733      17950       23900      1934             0
# 822       5000        5000      1931             0
# 894       1340        1312      2003             0
# 1175      2500        5000      2002             0
# 1360      6000        6000      1926             0

# %%
#b)
#Your code:
x = df['grade']
y = df['price']
df2 = df.loc[(df['bedrooms'] == 3) & (df['bathrooms'] == 2) & (df['floors'] == 2)]
df2.plot.scatter(x='grade',y='price')

# %%
#c) Find such apartments with best price to footage ratio.
#Your code:
df2['ratio'] = df2['price']/df2['sqft_living']
df2.sort_values(by=['ratio']).head(10)
#df2.ratio.sort_values().index.tolist()

#Hint: .loc, .sort_values(), .index
# Out:
#        bathrooms  bedrooms  condition             date  floors  grade  \
# 9704         2.0         3          3  20140829T000000     2.0      6
# 11258        2.0         3          3  20140710T000000     2.0      9
# 19880        2.0         3          3  20150319T000000     2.0      7
# 16014        2.0         3          3  20141113T000000     2.0      8
# 20906        2.0         3          3  20141028T000000     2.0      7
# 16177        2.0         3          4  20140604T000000     2.0      7
# 11940        2.0         3          4  20150429T000000     2.0      7
# 4540         2.0         3          4  20140929T000000     2.0      7
# 462          2.0         3          3  20141104T000000     2.0      7
# 16637        2.0         3          3  20150121T000000     2.0      7
#
#                id      lat     long     price  ...  sqft_living  \
# 9704   7452500565  47.5188 -122.373  260000.0  ...         2710
# 11258  7937600262  47.4343 -122.082  379900.0  ...         3110
# 19880  3832050860  47.3338 -122.053  210000.0  ...         1580
# 16014  5104450440  47.4619 -122.153  252500.0  ...         1810
# 20906  3355400242  47.2602 -122.246  274900.0  ...         1936
# 16177  2791500020  47.2917 -122.373  250500.0  ...         1710
# 11940   537000416  47.3255 -122.305  250000.0  ...         1680
# 4540   2522029039  47.3627 -122.496  550000.0  ...         3650
# 462    8944290160  47.3912 -122.167  230000.0  ...         1510
# 16637  6802200190  47.1955 -121.987  222500.0  ...         1450
#
#        sqft_living15  sqft_lot  sqft_lot15  view  waterfront  yr_built  \
# 9704             850      5000        5000     0           0      1951
# 11258           2150     44967       44967     0           0      1999
# 19880           2280      4961        5000     0           0      2006
# 16014           2140     10684        9657     0           0      1987
# 20906           1620      6612       21600     0           0      2014
# 16177           1710      7225        7225     0           0      1988
# 11940           1250      7900       15600     0           0      1953
# 4540            1870    843309      273992     0           0      1991
# 462             1570      3413        3777     0           0      1985
# 16637           1450      9044        9044     0           0      1990
#
#        yr_renovated  zipcode       ratio
# 9704              0    98126   95.940959
# 11258             0    98058  122.154341
# 19880             0    98042  132.911392
# 16014             0    98058  139.502762
# 20906             0    98001  141.993802
# 16177             0    98023  146.491228
# 11940             0    98003  148.809524
# 4540              0    98070  150.684932
# 462               0    98031  152.317881
# 16637             0    98022  153.448276
#
# [10 rows x 22 columns]
